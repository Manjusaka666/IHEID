# %%
import numpy as np
theta = 175
n = 10
u_i = np.random.uniform(-5, 5, n)
x_i = theta + u_i
theta_hat = np.mean(x_i)

print("Estiamted theta = ", theta_hat)
# Out:
# Estiamted theta =  175.27620432553718

# %%
import numpy as np
theta = 175
n = 100
u_i = np.random.uniform(-5, 5, n)
x_i = theta + u_i
theta_hat = np.mean(x_i)

print("Estiamted theta = ", theta_hat)
# Out:
# Estiamted theta =  175.09859744383778

# %%
import numpy as np
theta = 175
n = 1000
u_i = np.random.uniform(-5, 5, n)
x_i = theta + u_i
theta_hat = np.mean(x_i)

print("Estiamted theta = ", theta_hat)
# Out:
# Estiamted theta =  175.03889315916487

# %%
import numpy as np

# Parameters
theta = 175
n_values = [100, 1000]

# explicitly converting numpy floats to Python native floats
theta_hat = {n: float(np.mean(theta + np.random.uniform(-5, 5, n))) for n in n_values}

# Display estimated values of theta for different sample sizes
print("Estimated theta =", theta_hat)
# Out:
# Estimated theta = {100: 175.02607280264897, 1000: 174.99311421221367}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to simulate the LS estimator for given n and theta
def simulate_theta_hat(n, theta, M):
    theta_hats = []
    for _ in range(M):
        u_i = np.random.uniform(-5, 5, n)  # ui ~ U(-5, 5)
        x_i = theta + u_i
        theta_hat = np.mean(x_i)
        theta_hats.append(theta_hat)
    return theta_hats

# Parameters
theta = 175
n_values = [10, 100, 1000]
M = 100  # Number of datasets

# Simulations
results = {}
for n in n_values:
    results[n] = simulate_theta_hat(n, theta, M)

# Plotting the results
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
for ax, n in zip(axes, n_values):
    ax.hist(results[n], bins=20, edgecolor='black')
    ax.set_title(f'n = {n}')
    ax.set_xlabel(r'$\hat{\theta}$ values')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to simulate the LS estimator for given n and theta
def simulate_theta_hat(n, theta, M):
    theta_hats = []
    for _ in range(M):
        u_i = np.random.uniform(-5, 5, n)  # ui ~ U(-5, 5)
        x_i = theta + u_i
        theta_hat = np.mean(x_i)
        theta_hats.append(theta_hat)
    return theta_hats

# Parameters
theta = 175
M = 100  # Number of datasets

# Simulate and plot for n = 10
n = 10
theta_hats_10 = simulate_theta_hat(n, theta, M)
plt.figure(figsize=(6, 4))
plt.hist(theta_hats_10, bins=20, edgecolor='black')
plt.title(f'n = {n}')
plt.xlabel(r'$\hat{\theta}$ values')
plt.ylabel('Frequency')
plt.show()

# Simulate and plot for n = 100
n_values = [100, 1000]
results = {}
for n in n_values:
    results[n] = simulate_theta_hat(n, theta, M)
fig, axes = plt.subplots(1, 2, figsize=(18, 6))
for ax, n in zip(axes, n_values):
    ax.hist(results[n], bins=20, edgecolor='black')
    ax.set_title(f'n = {n}')
    ax.set_xlabel(r'$\hat{\theta}$ values')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()
